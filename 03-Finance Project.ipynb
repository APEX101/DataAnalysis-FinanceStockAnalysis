# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices

# %% [markdown]
# ## Get the Data

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks.

# %%
start=datetime.datetime(2006,1,1)
end=datetime.datetime(2016,1,1)
#bank of America
BAC = data.DataReader("BAC", 'yahoo', start, end)
#CitiGroup
C=data.DataReader("C",'yahoo',start,end)
#Goldman Sachs
GS=data.DataReader("GS",'yahoo',start,end)
#JPMorgan Chase
JPM=data.DataReader("JPM",'yahoo',start,end)
#Morgan Stanley
MS=data.DataReader("MS",'yahoo',start,end)
#Wells Fargo
WFC=data.DataReader("WFC",'yahoo',start,end)
WFC.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  31.975000  31.195000  31.600000  31.900000  11016400.0  20.613142
# 2006-01-04  31.820000  31.365000  31.799999  31.530001  10870000.0  20.374050
# 2006-01-05  31.555000  31.309999  31.500000  31.495001  10158000.0  20.351437
# 2006-01-06  31.775000  31.385000  31.580000  31.680000   8403800.0  20.470978
# 2006-01-09  31.825001  31.555000  31.674999  31.674999   5619600.0  20.467749

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers=['BAC','C','GS','JPM','MS','WFC']

tickers.sort
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
frames=[BAC,C,GS,JPM,MS,WFC]
tickers=['BAC','C','GS','JPM','MS','WFC']
bank_stocks=pd.concat(frames,keys=tickers,axis=1)
bank_stocks.head(10)
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.280807
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.916729
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.960411
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.909451
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.931290
# 2006-01-10  46.509998  45.880001  46.400002  46.209999  15634600.0  33.647324
# 2006-01-11  46.250000  45.750000  46.060001  46.099998  14742100.0  33.567226
# 2006-01-12  46.230000  45.709999  46.220001  45.799999  10546600.0  33.348785
# 2006-01-13  46.000000  45.680000  45.830002  45.799999  10791000.0  33.348785
# 2006-01-17  45.580002  45.000000  45.400002  45.310001  14605900.0  32.991993
#
# ...

# %% [markdown]
# ** Set the column name levels (this is filled out for you):**

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   34.280807  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   33.916729  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   33.960411  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
p=bank_stocks.xs(key='Close',level=1,axis=1).max()
p
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns=pd.DataFrame()
returns.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
returns.head()
returns=bank_stocks.pct_change().xs(key='Close',level=1,axis=1)
returns.rename(columns={'BAC' : 'BAC Returns','C':'C Returns','GS':'GS Returns','JPM':'JPM Returns' ,'MS':'MS Returns', 'WFC':'WFC Returns'},inplace=True)
returns.head()
# Out:
# Bank Ticker  BAC Returns  C Returns  GS Returns  JPM Returns  MS Returns  \
# Date
# 2006-01-03           NaN        NaN         NaN          NaN         NaN
# 2006-01-04     -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2006-01-05      0.001288   0.004961   -0.000393     0.003029    0.002742
# 2006-01-06     -0.001501   0.000000    0.014169     0.007046    0.001025
# 2006-01-09      0.000644  -0.004731    0.012030     0.016242    0.010586
#
# Bank Ticker  WFC Returns
# Date
# 2006-01-03           NaN
# 2006-01-04     -0.011599
# 2006-01-05     -0.001110
# 2006-01-06      0.005874
# 2006-01-09     -0.000158

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
import seaborn as sns
sns.pairplot(data=returns)

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
returns.head()
returns.idxmin()
# Out:
# Bank Ticker
# BAC Returns   2009-01-20
# C Returns     2009-02-27
# GS Returns    2009-01-20
# JPM Returns   2009-01-20
# MS Returns    2008-10-09
# WFC Returns   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# Bank Ticker
# BAC Returns   2009-04-09
# C Returns     2008-11-24
# GS Returns    2008-11-24
# JPM Returns   2009-01-21
# MS Returns    2008-10-13
# WFC Returns   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
returns.std()
# Out:
# Bank Ticker
# BAC Returns    0.036647
# C Returns      0.038672
# GS Returns     0.025390
# JPM Returns    0.027667
# MS Returns     0.037819
# WFC Returns    0.030238
# dtype: float64

# %%
returns.head(
)
returns.index
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# Bank Ticker
# BAC Returns    0.016163
# C Returns      0.015289
# GS Returns     0.014046
# JPM Returns    0.014017
# MS Returns     0.016249
# WFC Returns    0.012591
# dtype: float64

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
import matplotlib.pyplot as plt
sns.displot(returns.loc['2015-01-01':'2015-12-31']['MS Returns'],bins=100,kde=True,color='Green')

# %%
sns.displot(returns.loc['2015-01-01':'2015-12-31']['MS Returns'],bins=100,kde=True,color='Green')
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
sns.displot(returns.loc['2008-01-01':'2015-12-31']['C Returns'],bins=60,kde=True,color='red')

# %% [markdown]
# ____
# # More Visualization
#
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
q=bank_stocks.xs(key='Close',level=1,axis=1)
q.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
q=bank_stocks.xs(key='Close',level=1,axis=1).corr()

sns.heatmap(data=q,cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
q=bank_stocks.xs(key='Close',level=1,axis=1).corr()

sns.clustermap(data=q,cmap='coolwarm',annot=True)

# %% [markdown]
# # Part 2
#
# Here we will rely on the cufflinks library to create some Technical Analysis plots.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
import plotly.plotly as py
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

init_notebook_mode(connected=True)
cf.go_offline()

q=bank_stocks['BAC']
q=q.loc['2015-01-01':'2016-01-01']
q.iplot(kind='scatter')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
q=bank_stocks['BAC']
q=q['2015-01-01':'2015-12-31']['Close']
q
# Out:
# Date
# 2015-01-02    17.900000
# 2015-01-05    17.379999
# 2015-01-06    16.860001
# 2015-01-07    16.940001
# 2015-01-08    17.290001
#                 ...
# 2015-12-24    17.270000
# 2015-12-28    17.129999
# 2015-12-29    17.280001
# 2015-12-30    17.049999
# 2015-12-31    16.830000
# Name: Close, Length: 252, dtype: float64

# %% [markdown]
# # Great Job!
